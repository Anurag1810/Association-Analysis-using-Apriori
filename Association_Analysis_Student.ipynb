# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
#mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# load data into a pandas dataframe
data = pd.read_excel('gdrive/My Drive/Colab Notebooks/Activity 3/Data/Online Retail.xlsx')

# %%
# show the top 10 rows
data.head(10)
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
# 5    536365     22752  ...    17850.0  United Kingdom
# 6    536365     21730  ...    17850.0  United Kingdom
# 7    536366     22633  ...    17850.0  United Kingdom
# 8    536366     22632  ...    17850.0  United Kingdom
# 9    536367     84879  ...    13047.0  United Kingdom
#
# [10 rows x 8 columns]

# %%
# What are the columns of our data?
list(data.columns)
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
# What are the different regions that the transactions are from? (Countries)
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# Stripping extra spaces in the description 
data.Description.str.strip()
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905            CHILDREN'S APRON DOLLY GIRL
# 541906           CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908           BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
# Dropping the rows without any invoice number 
missingCount = data["InvoiceNo"].isnull().sum()
if missingCount == 0:
  print("There are no missing values in the column InvoiceNo.")
else:
  data['InvoiceNo'].dropna(inplace = True)

data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True) 
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
# Out:
# There are no missing values in the column InvoiceNo.

# %%
# Dropping all transactions which were done on credit 
data = data[~data['InvoiceNo'].str.contains('C')]
data
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [532621 rows x 8 columns]

# %%
# Splitting the data according to the region of transaction
# select data rows by country designated below
# use groupby('InvoiceNo', 'Description')['Quantity']
# sum data
# fillna(0)
# set_index('Invoice Number)
# Transactions done in France 
basket_France = (data[data['Country'] =="France"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
print("The number of transactions done in France are", len(basket_France.index))
basket_France
# Out:
# The number of transactions done in France are 392
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                                    ...
# 536370                                  0.0  ...                              0.0
# 536852                                  0.0  ...                              0.0
# 536974                                  0.0  ...                              0.0
# 537065                                  0.0  ...                              0.0
# 537463                                  0.0  ...                              0.0
# ...                                     ...  ...                              ...
# 580986                                  0.0  ...                              0.0
# 581001                                  0.0  ...                              0.0
# 581171                                  0.0  ...                              0.0
# 581279                                  0.0  ...                              0.0
# 581587                                  0.0  ...                              0.0
#
# [392 rows x 1564 columns]

# %%
# Transactions done in the United Kingdom 
basket_UK = (data[data['Country'] =="United Kingdom"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))
print("The number of transactions done in France are", len(basket_UK.index))
basket_UK
# Out:
# The number of transactions done in France are 18668
# Description  20713  ...  wrongly sold sets
# InvoiceNo           ...
# 536365         0.0  ...                0.0
# 536366         0.0  ...                0.0
# 536367         0.0  ...                0.0
# 536368         0.0  ...                0.0
# 536369         0.0  ...                0.0
# ...            ...  ...                ...
# 581585         0.0  ...                0.0
# 581586         0.0  ...                0.0
# A563185        0.0  ...                0.0
# A563186        0.0  ...                0.0
# A563187        0.0  ...                0.0
#
# [18668 rows x 4188 columns]

# %%
# Transactions done in Portugal 
basket_Por = (data[data['Country'] =="Portugal"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))
print("The number of transactions done in France are", len(basket_Por.index))
basket_Por
# Out:
# The number of transactions done in France are 58
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC WIRE KITCHEN ORGANISER
# InvoiceNo                                    ...
# 536990                                  0.0  ...                          0.0
# 537246                                  0.0  ...                          0.0
# 537818                                  0.0  ...                          0.0
# 537915                                  0.0  ...                          0.0
# 538311                                  0.0  ...                          0.0
# 539353                                  0.0  ...                          0.0
# 540519                                  0.0  ...                          0.0
# 540546                                  0.0  ...                          0.0
# 541430                                  0.0  ...                          0.0
# 542147                                  0.0  ...                          0.0
# 544495                                  0.0  ...                          0.0
# 545191                                  0.0  ...                          0.0
# 545937                                  0.0  ...                          0.0
# 547444                                  0.0  ...                          0.0
# 547566                                  0.0  ...                          0.0
# 547897                                  0.0  ...                          0.0
# 548470                                  0.0  ...                          0.0
# 549435                                  0.0  ...                          0.0
# 549953                                  0.0  ...                          0.0
# 553017                                  0.0  ...                          0.0
# 553018                                  0.0  ...                          0.0
# 554155                                  0.0  ...                          0.0
# 554301                                  0.0  ...                          0.0
# 554305                                  0.0  ...                          0.0
# 555862                                  0.0  ...                          0.0
# 556024                                  0.0  ...                          0.0
# 556829                                  0.0  ...                          0.0
# 559862                                  0.0  ...                          0.0
# 559907                                  0.0  ...                          0.0
# 560694                                  0.0  ...                          0.0
# 563241                                  0.0  ...                          0.0
# 565295                                  0.0  ...                          0.0
# 567929                                  0.0  ...                          0.0
# 568208                                 12.0  ...                          0.0
# 569866                                 20.0  ...                          0.0
# 569870                                  0.0  ...                          0.0
# 570499                                  0.0  ...                          0.0
# 570964                                 24.0  ...                          0.0
# 571188                                  0.0  ...                          0.0
# 571324                                  0.0  ...                          0.0
# 571326                                  0.0  ...                          0.0
# 571477                                  0.0  ...                          0.0
# 571901                                  0.0  ...                          0.0
# 572680                                  0.0  ...                          0.0
# 574099                                  0.0  ...                          0.0
# 574844                                  0.0  ...                          0.0
# 575743                                  0.0  ...                          0.0
# 576257                                  0.0  ...                          0.0
# 576269                                  0.0  ...                          0.0
# 576895                                  0.0  ...                          0.0
# 577618                                  0.0  ...                          0.0
# 578463                                  0.0  ...                          0.0
# 578488                                  0.0  ...                          1.0
# 579790                                  0.0  ...                          0.0
# 580153                                  0.0  ...                          0.0
# 580545                                  0.0  ...                          0.0
# 580734                                  0.0  ...                          0.0
# 581182                                  0.0  ...                          0.0
#
# [58 rows x 714 columns]

# %%
# Transactions done in Sweden
basket_Sweden = (data[data['Country'] =="Sweden"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))
print("The number of transactions done in France are", len(basket_Sweden.index))
basket_Sweden
# Out:
# The number of transactions done in France are 36
# Description  12 PENCIL SMALL TUBE WOODLAND  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                                   ...
# 538848                                 0.0  ...                               0.0
# 539338                                 0.0  ...                               0.0
# 540040                                 0.0  ...                               0.0
# 542428                                 0.0  ...                               0.0
# 542911                                 0.0  ...                               0.0
# 546161                                 0.0  ...                               0.0
# 546530                                 0.0  ...                               0.0
# 547645                                 0.0  ...                               0.0
# 550277                                 0.0  ...                               0.0
# 551278                                 0.0  ...                               0.0
# 552717                                 0.0  ...                               0.0
# 552957                                 0.0  ...                               0.0
# 553674                                 0.0  ...                               0.0
# 555403                                 0.0  ...                               0.0
# 556194                                 0.0  ...                               0.0
# 557939                                 0.0  ...                               0.0
# 559145                                 0.0  ...                               0.0
# 561890                                 0.0  ...                               0.0
# 561902                                 0.0  ...                               0.0
# 562285                                 0.0  ...                               0.0
# 562600                                 0.0  ...                               0.0
# 562650                                 0.0  ...                               0.0
# 563443                                 0.0  ...                               0.0
# 564539                                 0.0  ...                               0.0
# 565287                                 0.0  ...                               0.0
# 566494                                 0.0  ...                               0.0
# 569018                                 0.0  ...                               0.0
# 571191                                 0.0  ...                               0.0
# 571318                                 0.0  ...                               0.0
# 573333                                 0.0  ...                               0.0
# 574690                                24.0  ...                              12.0
# 575736                                 0.0  ...                               0.0
# 576083                                 0.0  ...                               0.0
# 576519                                 0.0  ...                               0.0
# 578089                                 0.0  ...                               0.0
# 580704                                 0.0  ...                               0.0
#
# [36 rows x 261 columns]

# %%
# Define a hot encoding function to make the data suitable  
# for the concerned libraries 
# value >= 1 -> 1 and similar for less than 0
def hot_encode(x):
      if(x <= 0): 
        return 0
      if(x >= 1): 
        return 1 
  
# Encoding the datasets 
# apply hot_encode function to data from above
basket_encoded = basket_France.applymap(hot_encode)
basket_France = basket_encoded 
  
basket_encoded = basket_UK.applymap(hot_encode)
basket_UK = basket_encoded 
  
basket_encoded = basket_Por.applymap(hot_encode)
basket_Por = basket_encoded 
  
basket_encoded = basket_Sweden.applymap(hot_encode)
basket_Sweden = basket_encoded

# %% [markdown]
# France:

# %%
# for each of the countries build a model
# view apriori documation
# min_support = 0.05

frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='lift' and mininum threshold = 1
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
# given the rules sort by confidence & lift, in descending order

rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head(10))
# Out:
#                                            antecedents  ... conviction
# 45                        (JUMBO BAG WOODLAND ANIMALS)  ...        inf
# 259  (PLASTERS IN TIN CIRCUS PARADE , RED TOADSTOOL...  ...        inf
# 271  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...  ...        inf
# 301  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...  ...  34.897959
# 302  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  34.489796
# 335  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS ,...  ...  28.790816
# 337  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES, SET/2...  ...  28.454082
# 129                         (RED RETROSPOT PICNIC BAG)  ...   6.571429
# 143                    (SET OF 9 BLACK SKULL BALLOONS)  ...   6.102041
# 174                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
#
# [10 rows x 9 columns]

# %% [markdown]
# United Kingdom

# %%
# for each of the countries build a model
# view apriori documation
# min_support = 0.05

frq_items = apriori(basket_UK, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='lift' and mininum threshold = 1
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
# given the rules sort by confidence & lift, in descending order

rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head(10))
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# for each of the countries build a model
# view apriori documation
# used min_support value as 0.04 as 0.05 value returned an empty frame
frq_items = apriori(basket_UK, min_support = 0.04, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='lift' and mininum threshold = 1
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
# given the rules sort by confidence & lift, in descending order

rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head(10))
# Out:
#                  antecedents                consequents  ...  leverage  conviction
# 0  (JUMBO BAG PINK POLKADOT)  (JUMBO BAG RED RETROSPOT)  ...  0.035605    2.777218
# 1  (JUMBO BAG RED RETROSPOT)  (JUMBO BAG PINK POLKADOT)  ...  0.035605    1.576478
#
# [2 rows x 9 columns]

# %% [markdown]
# Portugal

# %%
# for each of the countries build a model
# view apriori documation
# min_support = 0.05

frq_items = apriori(basket_Por, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='lift' and mininum threshold = 1
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
# given the rules sort by confidence & lift, in descending order

rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head(10))
# Out:
#                               antecedents  ... conviction
# 1170  (SET 12 COLOUR PENCILS DOLLY GIRL )  ...        inf
# 1171    (SET 12 COLOUR PENCILS SPACEBOY )  ...        inf
# 1172  (SET OF 4 KNICK KNACK TINS LONDON )  ...        inf
# 1173  (SET 12 COLOUR PENCILS DOLLY GIRL )  ...        inf
# 1174  (SET OF 4 KNICK KNACK TINS POPPIES)  ...        inf
# 1175  (SET 12 COLOUR PENCILS DOLLY GIRL )  ...        inf
# 1176  (SET OF 4 KNICK KNACK TINS LONDON )  ...        inf
# 1177    (SET 12 COLOUR PENCILS SPACEBOY )  ...        inf
# 1178  (SET OF 4 KNICK KNACK TINS POPPIES)  ...        inf
# 1179    (SET 12 COLOUR PENCILS SPACEBOY )  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# Sweden

# %%
# for each of the countries build a model
# view apriori documation
# min_support = 0.05

frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
# use association_rules with metric='lift' and mininum threshold = 1
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
# given the rules sort by confidence & lift, in descending order

rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.head(10))
# Out:
#                               antecedents  ... conviction
# 0           (12 PENCILS SMALL TUBE SKULL)  ...        inf
# 1           (PACK OF 72 SKULL CAKE CASES)  ...        inf
# 4                 (36 DOILIES DOLLY GIRL)  ...        inf
# 5         (ASSORTED BOTTLE TOP  MAGNETS )  ...        inf
# 180     (CHILDRENS CUTLERY CIRCUS PARADE)  ...        inf
# 181       (CHILDRENS CUTLERY DOLLY GIRL )  ...        inf
# 212  (FAIRY CAKE FLANNEL ASSORTED COLOUR)  ...        inf
# 213              (MOBILE VINTAGE HEARTS )  ...        inf
# 216                       (FIRST AID TIN)  ...        inf
# 217             (PHARMACIE FIRST AID TIN)  ...        inf
#
# [10 rows x 9 columns]
